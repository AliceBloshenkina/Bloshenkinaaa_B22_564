# %%
import numpy as np
import cv2
import os
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw, ImageFont
from pathlib import Path

def generate_alphabet_images(alphabet, font_path, font_size, output_dir):
    output_dir = Path(output_dir)
    output_dir.mkdir(parents=True, exist_ok=True)
    
    font = ImageFont.truetype(font_path, font_size)
    
    for char in alphabet:
        image = Image.new('L', (100, 100), 'white')
        draw = ImageDraw.Draw(image)
        
        bbox = draw.textbbox((0, 0), char, font=font)
        w, h = bbox[2] - bbox[0], bbox[3] - bbox[1]
        
        draw.text(((100 - w) / 2, (100 - h) / 2), char, 'black', font=font)
        
        bbox = image.getbbox()
        cropped_image = image.crop(bbox)
        cropped_image.save(output_dir / f'{char}.png')

def calculate_features(image_path):
    image_path = Path(image_path)
    if not image_path.exists():
        raise ValueError(f"Image file does not exist: {image_path}")

    try:
        pil_image = Image.open(image_path).convert('L')
        image = np.array(pil_image)
    except Exception as e:
        raise ValueError(f"Failed to load image {image_path} with PIL. Error: {e}")
    
    if image is None:
        raise ValueError(f"Failed to load image {image_path}")
    
    print(f"Image loaded successfully: {image_path}, shape: {image.shape}")
    
    h, w = image.shape
    total_mass = np.sum(image == 0)
    print(f"Total mass: {total_mass}")
    
    # Масса и удельный вес для каждой четверти изображения
    quarters = {
        'Q1': image[:h//2, :w//2],
        'Q2': image[:h//2, w//2:],
        'Q3': image[h//2:, :w//2],
        'Q4': image[h//2:, w//2:]
    }
    
    features = {}
    
    for key, quarter in quarters.items():
        mass = np.sum(quarter == 0)
        print(f"{key} mass: {mass}")
        features[f'{key}_mass'] = mass
        features[f'{key}_mass_normalized'] = mass / (quarter.size if quarter.size > 0 else 1)
    
    # Моменты инерции и центр тяжести
    binary_image = (image == 0).astype(np.uint8)  # Преобразование в тип uint8
    try:
        M = cv2.moments(binary_image)
        print(f"Moments: {M}")
    except Exception as e:
        raise ValueError(f"Error computing moments for {image_path}: {e}")
    
    cX = int(M["m10"] / M["m00"]) if M["m00"] != 0 else 0
    cY = int(M["m01"] / M["m00"]) if M["m00"] != 0 else 0
    features['center_of_mass_x'] = cX
    features['center_of_mass_y'] = cY
    
    # Нормированные координаты центра тяжести
    normalized_cX = cX / w if w > 0 else 0
    normalized_cY = cY / h if h > 0 else 0
    features['normalized_center_of_mass_x'] = normalized_cX
    features['normalized_center_of_mass_y'] = normalized_cY
    
    # Осевые моменты инерции
    mu20 = M["mu20"] / M["m00"] if M["m00"] != 0 else 0
    mu02 = M["mu02"] / M["m00"] if M["m00"] != 0 else 0
    features['inertia_horizontal'] = mu20
    features['inertia_vertical'] = mu02
    
    # Нормированные осевые моменты инерции
    normalized_mu20 = mu20 / (w * w + h * h) if (w * w + h * h) > 0 else 0
    normalized_mu02 = mu02 / (w * w + h * h) if (w * w + h * h) > 0 else 0
    features['normalized_inertia_horizontal'] = normalized_mu20
    features['normalized_inertia_vertical'] = normalized_mu02
    
    # Профили X и Y
    profile_x = np.sum(image == 0, axis=0)
    profile_y = np.sum(image == 0, axis=1)
    
    output_dir = Path('profiles')
    output_dir.mkdir(parents=True, exist_ok=True)
    np.savetxt(output_dir / f'{image_path.stem}_profile_x.txt', profile_x, fmt='%d')
    np.savetxt(output_dir / f'{image_path.stem}_profile_y.txt', profile_y, fmt='%d')
    
    return features

def plot_profiles(image_path, output_dir):
    output_dir = Path(output_dir)
    output_dir.mkdir(parents=True, exist_ok=True)
    
    image = cv2.imread(str(image_path), cv2.IMREAD_GRAYSCALE)
    if image is None:
        raise ValueError(f"Failed to load image {image_path}")
    
    x_profile = np.sum(image == 0, axis=0)
    y_profile = np.sum(image == 0, axis=1)
    
    char = os.path.splitext(os.path.basename(image_path))[0]
    
    plt.figure(figsize=(10, 4))
    
    plt.subplot(1, 2, 1)
    plt.bar(range(len(x_profile)), x_profile)
    plt.title(f'X Profile of {char}')
    plt.xlabel('X')
    plt.ylabel('Sum of Black Pixels')
    
    plt.subplot(1, 2, 2)
    plt.bar(range(len(y_profile)), y_profile)
    plt.title(f'Y Profile of {char}')
    plt.xlabel('Y')
    plt.ylabel('Sum of Black Pixels')
    
    plt.tight_layout()
    plt.savefig(output_dir / f'{char}_profile.png')
    plt.close()
    print(f"Profiles saved for {char}")

if __name__ == '__main__':
    alphabet = '1' 
    # ABCDEFGHIJKLMNOPQRSTUVWXYZÑ'
    font_path = 'times_new_roman1.ttf'
    font_size = 52
    output_dir = 'alphabet_images'
    profile_output_dir = 'profiles'


    # generate_alphabet_images(alphabet, font_path, font_size, output_dir)

    for image_file in Path(output_dir).iterdir():
        print(f"Found image file: {image_file}")

    output_features = []

    for char in alphabet:
        image_path = Path(output_dir) / f'{char}.png'
    
        try:
            print(f"Processing image: {image_path}")
            features = calculate_features(image_path)
            print(f"Features calculated for {char}: {features}")
            features['character'] = char
            output_features.append(features)
            plot_profiles(image_path, profile_output_dir)
            print(f"Profiles plotted for {char}")
        except (FileNotFoundError, ValueError) as e:
            print(e)

    try:
        df = pd.DataFrame(output_features)
        print(f"DataFrame created with {len(df)} entries")
        df.to_csv('features.csv', index=False, sep=';')
        print("Features saved to 'features.csv'")
    except Exception as e:
        print(f"Error creating DataFrame or saving CSV: {e}")
# Out:
# Found image file: alphabet_images\.ipynb_checkpoints
# Found image file: alphabet_images\1.png
# Found image file: alphabet_images\A.PNG
# Found image file: alphabet_images\B.PNG
# Found image file: alphabet_images\C.PNG
# Found image file: alphabet_images\D.PNG
# Found image file: alphabet_images\E.PNG
# Found image file: alphabet_images\F.PNG
# Found image file: alphabet_images\G.PNG
# Found image file: alphabet_images\H.PNG
# Found image file: alphabet_images\I.PNG
# Found image file: alphabet_images\J.PNG
# Found image file: alphabet_images\K.PNG
# Found image file: alphabet_images\L.PNG
# Found image file: alphabet_images\M.PNG
# Found image file: alphabet_images\N.PNG
# Found image file: alphabet_images\O.PNG
# Found image file: alphabet_images\P.PNG
# Found image file: alphabet_images\Q.PNG
# Found image file: alphabet_images\R.PNG
# Found image file: alphabet_images\S.PNG
# Found image file: alphabet_images\T.PNG
# Found image file: alphabet_images\U.PNG
# Found image file: alphabet_images\V.PNG
# Found image file: alphabet_images\W.PNG
# Found image file: alphabet_images\X.PNG
# Found image file: alphabet_images\Y.PNG
# Features calculated for G: {'Q1_mass': 613, 'Q1_mass_normalized': 0.14512310606060605, 'Q2_mass': 327, 'Q2_mass_normalized': 0.07741477272727272, 'Q3_mass': 760, 'Q3_mass_normalized': 0.17715617715617715, 'Q4_mass': 814, 'Q4_mass_normalized': 0.18974358974358974, 'center_of_mass_x': 62, 'center_of_mass_y': 70, 'normalized_center_of_mass_x': 0.4696969696969697, 'normalized_center_of_mass_y': 0.5426356589147286, 'inertia_horizontal': 1533.453353661817, 'inertia_vertical': 1106.1210888080052, 'normalized_inertia_horizontal': 0.045015510161802934, 'normalized_inertia_vertical': 0.032470896486364455}
# Profiles saved for G
# Profiles plotted for G
# Processing image: alphabet_images\H.png
# Image loaded successfully: alphabet_images\H.png, shape: (100, 101)
# Total mass: 1594
# Q1 mass: 463
# Q2 mass: 427
# Q3 mass: 369
# Q4 mass: 335
# Moments: {'m00': 1594.0, 'm10': 77555.0, 'm01': 74420.0, 'm20': 4912809.0, 'm11': 3622025.0, 'm02': 4616518.0, 'm30': 352543391.0, 'm21': 229181121.0, 'm12': 225326783.0, 'm03': 322673018.0, 'mu20': 1139422.5351317443, 'mu11': 1169.8557089087396, 'mu02': 1142028.414052698, 'mu30': 2638289.7331964555, 'mu21': -299871.5338825594, 'mu12': 603963.1670552411, 'mu03': 501889.57615840907, 'nu20': 0.4484439511765987, 'nu11': 0.0004604215734147106, 'nu02': 0.4494695502002876, 'nu30': 0.026007684900983704, 'nu21': -0.0029560681929134912, 'nu12': 0.005953737204420697, 'nu03': 0.004947518002885015}
# Features calculated for H: {'Q1_mass': 463, 'Q1_mass_normalized': 0.1852, 'Q2_mass': 427, 'Q2_mass_normalized': 0.16745098039215686, 'Q3_mass': 369, 'Q3_mass_normalized': 0.1476, 'Q4_mass': 335, 'Q4_mass_normalized': 0.13137254901960785, 'center_of_mass_x': 48, 'center_of_mass_y': 46, 'normalized_center_of_mass_x': 0.4752475247524752, 'normalized_center_of_mass_y': 0.46, 'inertia_horizontal': 714.8196581754984, 'inertia_vertical': 716.4544630192585, 'normalized_inertia_horizontal': 0.035385360040369206, 'normalized_inertia_vertical': 0.03546628696694513}
# Profiles saved for H
# Profiles plotted for H
# Processing image: alphabet_images\I.png
# Image loaded successfully: alphabet_images\I.png, shape: (143, 67)
# Total mass: 1686
# Q1 mass: 323
# Q2 mass: 535
# Q3 mass: 312
# Q4 mass: 516
# Moments: {'m00': 1686.0, 'm10': 57444.0, 'm01': 116650.0, 'm20': 1995812.0, 'm11': 3981647.0, 'm02': 10666472.0, 'm30': 70637898.0, 'm21': 138555979.0, 'm12': 363250651.0, 'm03': 1096593610.0, 'mu20': 38627.45907473288, 'mu11': 7244.508896796713, 'mu02': 2595758.773428233, 'mu30': 6073.536074780217, 'mu21': -22773.632345891838, 'mu12': -1171034.3461582873, 'mu03': -579866.062162849, 'nu20': 0.013588796675550406, 'nu11': 0.0025485538208020815, 'nu02': 0.9131648582592226, 'nu30': 5.2035255299668646e-05, 'nu21': -0.00019511397621230995, 'nu12': -0.010032882066849678, 'nu03': -0.0049680249220136995}
# Features calculated for I: {'Q1_mass': 323, 'Q1_mass_normalized': 0.13785744771660263, 'Q2_mass': 535, 'Q2_mass_normalized': 0.22162386081193042, 'Q3_mass': 312, 'Q3_mass_normalized': 0.13131313131313133, 'Q4_mass': 516, 'Q4_mass_normalized': 0.2107843137254902, 'center_of_mass_x': 34, 'center_of_mass_y': 69, 'normalized_center_of_mass_x': 0.5074626865671642, 'normalized_center_of_mass_y': 0.4825174825174825, 'inertia_horizontal': 22.91071119497798, 'inertia_vertical': 1539.595951025049, 'normalized_inertia_horizontal': 0.0009187068407642145, 'normalized_inertia_vertical': 0.061736945666254275}
# Profiles saved for I
# Profiles plotted for I
# Processing image: alphabet_images\J.png
# Image loaded successfully: alphabet_images\J.png, shape: (120, 65)
# Total mass: 1080
# Q1 mass: 10
# Q2 mass: 545
# Q3 mass: 184
# Q4 mass: 341
# Moments: {'m00': 1080.0, 'm10': 38785.0, 'm01': 63136.0, 'm20': 1508405.0, 'm11': 2044965.0, 'm02': 4898716.0, 'm30': 60624853.0, 'm21': 75767223.0, 'm12': 144558251.0, 'm03': 428885830.0, 'mu20': 115556.64351851848, 'mu11': -222377.37037037042, 'mu02': 1207832.2074074072, 'mu30': -1844792.1506772926, 'mu21': 3559032.7589163226, 'mu12': -5364586.730178319, 'mu03': 1292569.0094924807, 'nu20': 0.09907119643220035, 'nu11': -0.19065275237514612, 'nu02': 1.0355214398211654, 'nu30': -0.04812691828772398, 'nu21': 0.09284800930490376, 'nu12': -0.13995128237937934, 'nu03': 0.033720526769506404}
# Features calculated for J: {'Q1_mass': 10, 'Q1_mass_normalized': 0.005208333333333333, 'Q2_mass': 545, 'Q2_mass_normalized': 0.27525252525252525, 'Q3_mass': 184, 'Q3_mass_normalized': 0.09583333333333334, 'Q4_mass': 341, 'Q4_mass_normalized': 0.17222222222222222, 'center_of_mass_x': 35, 'center_of_mass_y': 58, 'normalized_center_of_mass_x': 0.5384615384615384, 'normalized_center_of_mass_y': 0.48333333333333334, 'inertia_horizontal': 106.99689214677637, 'inertia_vertical': 1118.3631550068585, 'normalized_inertia_horizontal': 0.005744799578350409, 'normalized_inertia_vertical': 0.060046343892985694}
# Profiles saved for J
# Profiles plotted for J
# Processing image: alphabet_images\K.png
# Image loaded successfully: alphabet_images\K.png, shape: (141, 153)
# Total mass: 3296
# Q1 mass: 1034
# Q2 mass: 243
# Q3 mass: 1166
# Q4 mass: 853
# Moments: {'m00': 3296.0, 'm10': 190100.0, 'm01': 252146.0, 'm20': 14288464.0, 'm11': 15715389.0, 'm02': 24232556.0, 'm30': 1262546996.0, 'm21': 1259082391.0, 'm12': 1603416905.0, 'm03': 2538220430.0, 'mu20': 3324261.9368932047, 'mu11': 1172623.6480582533, 'mu02': 4943233.998786409, 'mu30': 54985893.20667596, 'mu21': 30741810.072892096, 'mu12': 26367869.706737738, 'mu03': -71905609.105581, 'nu20': 0.30599958033247904, 'nu11': 0.10794045445441493, 'nu02': 0.45502657667450774, 'nu30': 0.08816237410592459, 'nu21': 0.04929029615200529, 'nu12': 0.042277279823826654, 'nu03': -0.11529082898504107}
# Features calculated for Q: {'Q1_mass': 1053, 'Q1_mass_normalized': 0.1653061224489796, 'Q2_mass': 1068, 'Q2_mass_normalized': 0.16766091051805337, 'Q3_mass': 574, 'Q3_mass_normalized': 0.09010989010989011, 'Q4_mass': 805, 'Q4_mass_normalized': 0.12637362637362637, 'center_of_mass_x': 69, 'center_of_mass_y': 81, 'normalized_center_of_mass_x': 0.4928571428571429, 'normalized_center_of_mass_y': 0.44505494505494503, 'inertia_horizontal': 1895.7511884897956, 'inertia_vertical': 1684.1977530612244, 'normalized_inertia_horizontal': 0.03595613361068575, 'normalized_inertia_vertical': 0.031943664233768765}
# Profiles saved for Q
# Profiles plotted for Q
# Processing image: alphabet_images\R.png
# Image loaded successfully: alphabet_images\R.png, shape: (139, 138)
# Total mass: 3520
# Q1 mass: 992
# Q2 mass: 768
# Q3 mass: 954
# Q4 mass: 806
# Moments: {'m00': 3520.0, 'm10': 208515.0, 'm01': 239476.0, 'm20': 15365771.0, 'm11': 14497216.0, 'm02': 21423322.0, 'm30': 1286128947.0, 'm21': 1103004538.0, 'm12': 1321603498.0, 'm03': 2156110714.0, 'mu20': 3013922.9247159096, 'mu11': 311324.48295454605, 'mu02': 5131062.177272728, 'mu30': 18830646.613842104, 'mu21': 20741746.772007313, 'mu12': 10184898.400555287, 'mu03': 456182.4087706504, 'nu20': 0.24324662034445296, 'nu11': 0.025126265734322223, 'nu02': 0.4141159427680081, 'nu30': 0.025615838385254434, 'nu21': 0.028215559669047662, 'nu12': 0.01385479302697344, 'nu03': 0.0006205572807401758}
# Features calculated for R: {'Q1_mass': 992, 'Q1_mass_normalized': 0.20835958832178114, 'Q2_mass': 768, 'Q2_mass_normalized': 0.16131064902331443, 'Q3_mass': 954, 'Q3_mass_normalized': 0.19751552795031055, 'Q4_mass': 806, 'Q4_mass_normalized': 0.16687370600414078, 'center_of_mass_x': 59, 'center_of_mass_y': 68, 'normalized_center_of_mass_x': 0.427536231884058, 'normalized_center_of_mass_y': 0.4892086330935252, 'inertia_horizontal': 856.2281036124743, 'inertia_vertical': 1457.6881185433886, 'normalized_inertia_horizontal': 0.022317948745274974, 'normalized_inertia_vertical': 0.03799525918267662}
# Profiles saved for R
# Profiles plotted for R
# Processing image: alphabet_images\S.png
# Image loaded successfully: alphabet_images\S.png, shape: (178, 117)
# Total mass: 3412
# Q1 mass: 1346
# Q2 mass: 354
# Q3 mass: 396
# Q4 mass: 1316
# Moments: {'m00': 3412.0, 'm10': 189506.0, 'm01': 304437.0, 'm20': 13602680.0, 'm11': 18264982.0, 'm02': 33142935.0, 'm30': 1091830172.0, 'm21': 1374943930.0, 'm12': 2067994036.0, 'm03': 4011486735.0, 'mu20': 3077321.255568582, 'mu11': 1356236.946658852, 'mu02': 5979427.68200469, 'mu30': -5511902.969390213, 'mu21': 10586025.900625844, 'mu12': -14820282.514056677, 'mu03': -12737694.38098568, 'nu20': 0.26433507347082896, 'nu11': 0.11649774695774552, 'nu02': 0.5136195815682505, 'nu30': -0.00810548501985866, 'nu21': 0.015567196090690842, 'nu12': -0.02179384843580606, 'nu03': -0.01873131504055475}
# Features calculated for S: {'Q1_mass': 1346, 'Q1_mass_normalized': 0.2607516466485858, 'Q2_mass': 354, 'Q2_mass_normalized': 0.06741573033707865, 'Q3_mass': 396, 'Q3_mass_normalized': 0.07671445176288261, 'Q4_mass': 1316, 'Q4_mass_normalized': 0.2506189297276709, 'center_of_mass_x': 55, 'center_of_mass_y': 89, 'normalized_center_of_mass_x': 0.4700854700854701, 'normalized_center_of_mass_y': 0.5, 'inertia_horizontal': 901.9112706824684, 'inertia_vertical': 1752.4700123108705, 'normalized_inertia_horizontal': 0.01987770856417844, 'normalized_inertia_vertical': 0.03862363106496971}
# Profiles saved for S
# Profiles plotted for S
# Processing image: alphabet_images\T.png
# Image loaded successfully: alphabet_images\T.png, shape: (151, 136)
# Total mass: 2382
# Q1 mass: 659
# Q2 mass: 800
# Q3 mass: 400
# Q4 mass: 523
# Moments: {'m00': 2382.0, 'm10': 163192.0, 'm01': 142628.0, 'm20': 12166734.0, 'm11': 9754976.0, 'm02': 13764266.0, 'm30': 969083224.0, 'm21': 680517324.0, 'm12': 940462960.0, 'm03': 1538117444.0, 'mu20': 986369.2376154494, 'mu11': -16538.935348446597, 'mu02': 5224070.204869857, 'mu30': 380960.2813262796, 'mu21': -45729062.68229748, 'mu12': -553104.874157632, 'mu03': 88341162.97214277, 'nu20': 0.17384251844322368, 'nu11': -0.002914902516925958, 'nu02': 0.9207155761814676, 'nu30': 0.0013757049688947717, 'nu21': -0.16513453459222194, 'nu12': -0.0019973450278058746, 'nu03': 0.31901324840379386}
# Features calculated for T: {'Q1_mass': 659, 'Q1_mass_normalized': 0.1292156862745098, 'Q2_mass': 800, 'Q2_mass_normalized': 0.1568627450980392, 'Q3_mass': 400, 'Q3_mass_normalized': 0.07739938080495357, 'Q4_mass': 523, 'Q4_mass_normalized': 0.10119969040247678, 'center_of_mass_x': 68, 'center_of_mass_y': 59, 'normalized_center_of_mass_x': 0.5, 'normalized_center_of_mass_y': 0.39072847682119205, 'inertia_horizontal': 414.0928789317588, 'inertia_vertical': 2193.1445024642558, 'normalized_inertia_horizontal': 0.010027190326942848, 'normalized_inertia_vertical': 0.053106630081222746}
# Profiles saved for T
# Profiles plotted for T
# Processing image: alphabet_images\U.png
# Image loaded successfully: alphabet_images\U.png, shape: (154, 162)
# Total mass: 2489
# Q1 mass: 973
# Q2 mass: 366
# Q3 mass: 863
# Q4 mass: 287
# Moments: {'m00': 2489.0, 'm10': 151546.0, 'm01': 179236.0, 'm20': 13193442.0, 'm11': 10904877.0, 'm02': 17779382.0, 'm30': 1453196998.0, 'm21': 904765181.0, 'm12': 1101536631.0, 'm03': 2004091258.0, 'mu20': 3966366.8228204106, 'mu11': -8139.816392124588, 'mu02': 4872373.685014063, 'mu30': 166902335.72829106, 'mu21': -44319855.99561192, 'mu12': 20188166.431787055, 'mu03': 22044310.725447774, 'nu20': 0.6402404122244603, 'nu11': -0.0013139075721240292, 'nu02': 0.7864856368445527, 'nu30': 0.540007974139534, 'nu21': -0.1433956903353837, 'nu12': 0.06531826417437697, 'nu03': 0.0713237686231711}
# Features calculated for U: {'Q1_mass': 973, 'Q1_mass_normalized': 0.15600448933782268, 'Q2_mass': 366, 'Q2_mass_normalized': 0.05868205868205868, 'Q3_mass': 863, 'Q3_mass_normalized': 0.1383678050344717, 'Q4_mass': 287, 'Q4_mass_normalized': 0.04601571268237935, 'center_of_mass_x': 60, 'center_of_mass_y': 72, 'normalized_center_of_mass_x': 0.37037037037037035, 'normalized_center_of_mass_y': 0.4675324675324675, 'inertia_horizontal': 1593.5583860266815, 'inertia_vertical': 1957.562750106092, 'normalized_inertia_horizontal': 0.031896685068588504, 'normalized_inertia_vertical': 0.03918260108298823}
# Profiles saved for U
# Profiles plotted for U
# Processing image: alphabet_images\V.png
# Image loaded successfully: alphabet_images\V.png, shape: (169, 176)
# Total mass: 2842
# Q1 mass: 1325
# Q2 mass: 396
# Q3 mass: 680
# Q4 mass: 441
# Moments: {'m00': 2842.0, 'm10': 217418.0, 'm01': 193703.0, 'm20': 19817500.0, 'm11': 15620743.0, 'm02': 18977785.0, 'm30': 2091401510.0, 'm21': 1355114967.0, 'm12': 1594410965.0, 'm03': 2120751893.0, 'mu20': 3184640.4912033775, 'mu11': 802122.7135819842, 'mu02': 5775514.694229415, 'mu30': 88066693.80263485, 'mu21': -118319598.37056158, 'mu12': 33236013.871237908, 'mu03': 39990832.659521066, 'nu20': 0.39428682500050477, 'nu11': 0.09930992803508647, 'nu02': 0.7150601010762725, 'nu30': 0.20452740511645956, 'nu21': -0.2747872025647523, 'nu12': 0.07718781505222769, 'nu03': 0.09287530710110176}
# Features calculated for V: {'Q1_mass': 1325, 'Q1_mass_normalized': 0.1792478354978355, 'Q2_mass': 396, 'Q2_mass_normalized': 0.05357142857142857, 'Q3_mass': 680, 'Q3_mass_normalized': 0.09090909090909091, 'Q4_mass': 441, 'Q4_mass_normalized': 0.0589572192513369, 'center_of_mass_x': 76, 'center_of_mass_y': 68, 'normalized_center_of_mass_x': 0.4318181818181818, 'normalized_center_of_mass_y': 0.40236686390532544, 'inertia_horizontal': 1120.5631566514348, 'inertia_vertical': 2032.2008072587666, 'normalized_inertia_horizontal': 0.018821290233828288, 'normalized_inertia_vertical': 0.03413340959838028}
# Profiles saved for V
# Profiles plotted for V
# Processing image: alphabet_images\W.png
# Image loaded successfully: alphabet_images\W.png, shape: (185, 254)
# Total mass: 6401
# Q1 mass: 2108
# Q2 mass: 1549
# Q3 mass: 1349
# Q4 mass: 1395
# Moments: {'m00': 6401.0, 'm10': 727827.0, 'm01': 509937.0, 'm20': 100257651.0, 'm11': 60588225.0, 'm02': 55047099.0, 'm30': 15564004995.0, 'm21': 8322684221.0, 'm12': 6715376921.0, 'm03': 6706300767.0, 'mu20': 17499934.71676301, 'mu11': 2605735.2485549157, 'mu02': 14422861.541946571, 'mu30': 184521269.86768773, 'mu21': -256933762.9848392, 'mu12': 41062508.44607199, 'mu03': 22961598.90216838, 'nu20': 0.4271110173005504, 'nu11': 0.06359670769286473, 'nu02': 0.3520106311976711, 'nu30': 0.0562894320529252, 'nu21': -0.0783793413301786, 'nu12': 0.012526389400827512, 'nu03': 0.007004587396113856}
# Features calculated for W: {'Q1_mass': 2108, 'Q1_mass_normalized': 0.18041766518315647, 'Q2_mass': 1549, 'Q2_mass_normalized': 0.13257446080109553, 'Q3_mass': 1349, 'Q3_mass_normalized': 0.11421556176445687, 'Q4_mass': 1395, 'Q4_mass_normalized': 0.11811023622047244, 'center_of_mass_x': 113, 'center_of_mass_y': 79, 'normalized_center_of_mass_x': 0.4448818897637795, 'normalized_center_of_mass_y': 0.42702702702702705, 'inertia_horizontal': 2733.937621740823, 'inertia_vertical': 2253.220050296293, 'normalized_inertia_horizontal': 0.027687967731143324, 'normalized_inertia_vertical': 0.0228194979825634}
# Profiles saved for W
# Profiles plotted for W
# Processing image: alphabet_images\X.png
# Image loaded successfully: alphabet_images\X.png, shape: (201, 213)
# Total mass: 5797
# Q1 mass: 2082
# Q2 mass: 783
# Q3 mass: 730
# Q4 mass: 2202
# Moments: {'m00': 5797.0, 'm10': 625304.0, 'm01': 581013.0, 'm20': 78400794.0, 'm11': 67872566.0, 'm02': 80026975.0, 'm30': 10792418528.0, 'm21': 9085410016.0, 'm12': 9629621616.0, 'm03': 12391890219.0, 'mu20': 10951235.190960847, 'mu11': 5200536.855269971, 'mu02': 21794077.61014318, 'mu30': -26976405.77145929, 'mu21': 105642287.8962455, 'mu12': -45097482.70311203, 'mu03': 2378807.118123296, 'nu20': 0.3258790978196519, 'nu11': 0.15475389113842353, 'nu02': 0.6485327203334215, 'nu30': -0.010543282288932634, 'nu21': 0.04128854200870643, 'nu12': -0.01762560567509754, 'nu03': 0.0009297174415959826}
# Features calculated for X: {'Q1_mass': 2082, 'Q1_mass_normalized': 0.19641509433962265, 'Q2_mass': 783, 'Q2_mass_normalized': 0.07317757009345795, 'Q3_mass': 730, 'Q3_mass_normalized': 0.0681860638894078, 'Q4_mass': 2202, 'Q4_mass_normalized': 0.20375682428055888, 'center_of_mass_x': 107, 'center_of_mass_y': 100, 'normalized_center_of_mass_x': 0.5023474178403756, 'normalized_center_of_mass_y': 0.4975124378109453, 'inertia_horizontal': 1889.121130060522, 'inertia_vertical': 3759.544179772845, 'normalized_inertia_horizontal': 0.022025429987880634, 'normalized_inertia_vertical': 0.04383285740670217}
# Profiles saved for X
# Profiles plotted for X
# Processing image: alphabet_images\Y.png
# Image loaded successfully: alphabet_images\Y.png, shape: (219, 238)
# Total mass: 5638
# Q1 mass: 2591
# Q2 mass: 718
# Q3 mass: 1248
